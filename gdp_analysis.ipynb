# %%
from fed.data import data_load

data = data_load()
data.head()
# Out:
# /Users/lsahar/Documents/Projects/D100_ps1_ex2/fed/data.py:29: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   data = wb.download(indicator=indicator,
# country    Brazil     China   Germany     Japan  Switzerland  United Kingdom  \
# year
# 2000     0.655448  1.223755  1.966981  4.968359     0.279216        1.665535
# 2001     0.559984  1.355037  1.966381  4.374712     0.286583        1.649827
# 2002     0.509795  1.489822  2.102351  4.182846     0.309301        1.785730
# 2003     0.558234  1.683903  2.534716  4.519562     0.362075        2.054423
# 2004     0.669289  1.984197  2.852318  4.893116     0.403913        2.421525
#
# country  United States
# year
# 2000         10.250952
# 2001         10.581929
# 2002         10.929108
# 2003         11.456450
# 2004         12.217196

# %%
from fed.plot_utils import plot_line

plot_line(data)
# Out:
# <Axes: title={'center': 'GDP (Trillions USD) 2000–2022'}, xlabel='Year', ylabel='GDP (Trillions USD)'>
